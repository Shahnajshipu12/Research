# %%
# !nvidia-smi
# Out:
# Mon Sep 30 15:12:46 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   58C    P8              10W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content/drive/MyDrive/Research/Pothole

# %%
# %cd /content
# Out:
# /content

# %%
# !pip install -r /content/drive/MyDrive/Research/Pothole/yolov9/requirements.txt

# %%
# !wget -P {HOME}/weights -q https://github.com/WongKinYiu/yolov9/releases/download/v0.1/yolov9-c.pt

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# %cd /content/drive/MyDrive/Research/Pothole
# Out:
# /content/drive/MyDrive/Research/Pothole

# %%
# %cd {HOME}/yolov9

# !python train_dual.py \
--batch 8 --epochs 10 --img 640 --device 0 --min-items 0 --close-mosaic 15 \
--data /content/drive/MyDrive/Research/Pothole/yolov9/PD/data.yaml\
--weights /content/weights/yolov9-c.pt \
--cfg /content/drive/MyDrive/Research/Pothole/yolov9/models/detect/yolov9-c.yaml \
--hyp hyp.scratch-high.yaml
# Out:
# /content/drive/MyDrive/Research/Pothole/yolov9
# 2024-09-30 15:44:07.976121: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-09-30 15:44:07.996494: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-09-30 15:44:08.002648: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-09-30 15:44:08.017622: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# ...

# %%
# %cd {HOME}/yolov9

# !python train_dual.py \
--batch 8 --epochs 10 --img 640 --device 0 --min-items 0 --close-mosaic 15 \
--data /content/drive/MyDrive/Research/Pothole/yolov9/PD/data.yaml\
--weights /content/weights/yolov9-c.pt \
--cfg /content/drive/MyDrive/Research/Pothole/yolov9/models/detect/yolov9-modified.yaml \
--hyp hyp.scratch-high.yaml
# Out:
# /content/drive/MyDrive/Research/Pothole/yolov9
# 2024-09-30 16:32:52.679813: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-09-30 16:32:52.700160: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-09-30 16:32:52.706181: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-09-30 16:32:52.720536: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# ...
